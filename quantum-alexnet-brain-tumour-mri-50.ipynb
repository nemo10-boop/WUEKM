# %%
# !pip install pennylane pennylane-lightning -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 57.1 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 937.5/937.5 kB 42.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.5/25.5 MB 64.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 83.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 96.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.2/167.2 kB 13.5 MB/s eta 0:00:00

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms, models
import pennylane as qml
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import json

# %%
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {DEVICE}")

n_qubits = 8
dev = qml.device("lightning.qubit", wires=n_qubits)
# Out:
# Using device: cuda

# %%
N_EPOCHS      = 50
BATCH_SIZE    = 32
LEARNING_RATE = 0.001
TRAIN_SUBSET  = 1500
TEST_SUBSET   = 500

NOISE_LEVELS = [0.0, 0.005, 0.05, 0.10]

# %%
BRAIN_TRAIN_DIR = ("/kaggle/input/datasets/masoudnickparvar/"
                   "brain-tumor-mri-dataset/Training")
BRAIN_TEST_DIR  = ("/kaggle/input/datasets/masoudnickparvar/"
                   "brain-tumor-mri-dataset/Testing")

SAVE_DIR = "/kaggle/working/brain_checkpoints"
os.makedirs(SAVE_DIR, exist_ok=True)

# %%
@qml.qnode(dev, interface="torch", diff_method="adjoint")
def quantum_circuit(inputs, weights):
    for i in range(n_qubits):
        qml.RY(inputs[i], wires=i)
    num_layers = weights.shape[0]
    for layer in range(num_layers):
        for i in range(n_qubits):
            qml.CNOT(wires=[i, (i + 1) % n_qubits])
        for i in range(n_qubits):
            qml.RZ(weights[layer, i], wires=i)
    return [qml.expval(qml.PauliZ(wires=i)) for i in range(n_qubits)]

weight_shapes = {"weights": (8, n_qubits)}
quantum_layer = qml.qnn.TorchLayer(quantum_circuit, weight_shapes)

# %%
class QuantumAlexNet(nn.Module):
    def __init__(self, q_layer, n_qubits, n_classes=4):
        super(QuantumAlexNet, self).__init__()
        alexnet = models.alexnet(weights=models.AlexNet_Weights.DEFAULT)
        self.features = alexnet.features
        for param in self.features.parameters():
            param.requires_grad = False
        self.avgpool = alexnet.avgpool
        self.flatten = nn.Flatten()
        self.dense1 = nn.Linear(9216, 512)
        self.bn1    = nn.BatchNorm1d(512)
        self.act1   = nn.LeakyReLU(0.1)
        self.dense2 = nn.Linear(512, 128)
        self.bn2    = nn.BatchNorm1d(128)
        self.act2   = nn.LeakyReLU(0.1)
        self.linear_reduction = nn.Linear(128, n_qubits)
        self.quantum_layer    = q_layer
        self.classifier       = nn.Linear(n_qubits, n_classes)

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = self.flatten(x)
        x = self.act1(self.bn1(self.dense1(x)))
        x = self.act2(self.bn2(self.dense2(x)))
        x = self.linear_reduction(x)
        x = torch.sin(x) * (np.pi / 2)
        quantum_outputs = [self.quantum_layer(item) for item in x]
        x = torch.stack(quantum_outputs)
        x = self.classifier(x)
        return x

# %%
class AddGaussianNoise:
    def __init__(self, std=0.0):
        self.std = std
    def __call__(self, tensor):
        if self.std == 0.0:
            return tensor
        return torch.clamp(tensor + torch.randn_like(tensor) * self.std, 0.0, 1.0)

# %%
def build_loaders_brain(noise_std=0.0):
    noise_step = [AddGaussianNoise(std=noise_std)] if noise_std > 0.0 else []
    tf = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225]),
    ] + noise_step)
    train_full = datasets.ImageFolder(root=BRAIN_TRAIN_DIR, transform=tf)
    test_full  = datasets.ImageFolder(root=BRAIN_TEST_DIR,  transform=tf)
    train_loader = DataLoader(
        Subset(train_full, list(range(min(TRAIN_SUBSET, len(train_full))))),
        batch_size=BATCH_SIZE, shuffle=True,
    )
    test_loader = DataLoader(
        Subset(test_full, list(range(min(TEST_SUBSET, len(test_full))))),
        batch_size=BATCH_SIZE, shuffle=False,
    )
    print(f"Brain MRI | noise={noise_std} | train={min(TRAIN_SUBSET, len(train_full))} | test={min(TEST_SUBSET, len(test_full))} | classes=4")
    return train_loader, test_loader

# %%
def train_one_epoch(model, loader, criterion, optimizer):
    model.train()
    total_loss, correct, total = 0.0, 0, 0
    for images, labels in loader:
        images, labels = images.to(DEVICE), labels.to(DEVICE)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * images.size(0)
        correct    += (outputs.argmax(dim=1) == labels).sum().item()
        total      += images.size(0)
    return total_loss / total, correct / total

def evaluate(model, loader, criterion):
    model.eval()
    total_loss, correct, total = 0.0, 0, 0
    all_preds, all_labels = [], []
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            loss = criterion(outputs, labels)
            total_loss += loss.item() * images.size(0)
            preds = outputs.argmax(dim=1)
            correct += (preds == labels).sum().item()
            total   += images.size(0)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    return total_loss / total, correct / total, all_preds, all_labels

def save_checkpoint(noise_std, epoch, model, optimizer, history):
    noise_tag = str(noise_std).replace(".", "_")
    path = os.path.join(SAVE_DIR, f"ckpt_noise{noise_tag}_epoch{epoch}.pth")
    torch.save({
        "epoch":                epoch,
        "model_state_dict":     model.state_dict(),
        "optimizer_state_dict": optimizer.state_dict(),
        "history":              history,
    }, path)
    json_path = os.path.join(SAVE_DIR, f"history_noise{noise_tag}.json")
    json_history = {k: v for k, v in history.items() if k != "cm"}
    with open(json_path, "w") as f:
        json.dump(json_history, f)
    print(f"  [Saved checkpoint: {path}]")

def load_latest_checkpoint(noise_std, model, optimizer):
    noise_tag = str(noise_std).replace(".", "_")
    files = [
        f for f in os.listdir(SAVE_DIR)
        if f.startswith(f"ckpt_noise{noise_tag}_epoch") and f.endswith(".pth")
    ]
    if not files:
        return 0, {"train_loss": [], "train_acc": [], "test_loss": [], "test_acc": []}
    latest = sorted(files, key=lambda x: int(x.split("_epoch")[1].replace(".pth", "")))[-1]
    path = os.path.join(SAVE_DIR, latest)
    checkpoint = torch.load(path, map_location=DEVICE)
    model.load_state_dict(checkpoint["model_state_dict"])
    optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
    print(f"  [Resumed from checkpoint: {path}]")
    return checkpoint["epoch"], checkpoint["history"]

def save_final_results(results):
    for noise, history in results.items():
        noise_tag = str(noise).replace(".", "_")
        if "cm" in history:
            np.save(os.path.join(SAVE_DIR, f"cm_noise{noise_tag}.npy"), history["cm"])
    json_results = {}
    for noise, history in results.items():
        noise_tag = str(noise).replace(".", "_")
        json_results[noise_tag] = {k: v for k, v in history.items() if k != "cm"}
    with open(os.path.join(SAVE_DIR, "all_results.json"), "w") as f:
        json.dump(json_results, f)
    print(f"\n[All results saved to {SAVE_DIR}]")

# %%
def run_experiment_brain(noise_std):
    print(f"\nBrain MRI | noise={noise_std * 100:.1f}%")
    print("\n")

    train_loader, test_loader = build_loaders_brain(noise_std=noise_std)
    model     = QuantumAlexNet(quantum_layer, n_qubits, n_classes=4).to(DEVICE)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(
        filter(lambda p: p.requires_grad, model.parameters()),
        lr=LEARNING_RATE
    )

    start_epoch, history = load_latest_checkpoint(noise_std, model, optimizer)
    if start_epoch > 0:
        print(f"  [Resuming from epoch {start_epoch + 1}]")

    for epoch in range(start_epoch + 1, N_EPOCHS + 1):
        tr_loss, tr_acc = train_one_epoch(model, train_loader, criterion, optimizer)
        te_loss, te_acc, preds, labels = evaluate(model, test_loader, criterion)

        history["train_loss"].append(tr_loss)
        history["train_acc"].append(tr_acc)
        history["test_loss"].append(te_loss)
        history["test_acc"].append(te_acc)

        print(f"Epoch [{epoch}/{N_EPOCHS}] "
              f"Train Loss: {tr_loss:.4f} | Train Acc: {tr_acc*100:.2f}% | "
              f"Test Loss: {te_loss:.4f} | Test Acc: {te_acc*100:.2f}%")

        save_checkpoint(noise_std, epoch, model, optimizer, history)

    precision = precision_score(labels, preds, average="weighted", zero_division=0)
    recall    = recall_score(labels, preds, average="weighted", zero_division=0)
    f1        = f1_score(labels, preds, average="weighted", zero_division=0)
    cm        = confusion_matrix(labels, preds)

    history["precision"] = precision
    history["recall"]    = recall
    history["f1"]        = f1
    history["cm"]        = cm

    print(f"\nFinal Metrics | Precision: {precision:.4f} | Recall: {recall:.4f} | F1: {f1:.4f}")
    return history

# %%
results = {}
for noise in NOISE_LEVELS:
    results[noise] = run_experiment_brain(noise)

save_final_results(results)
print("\nAll experiments complete.")
# Out:
# Brain MRI | noise=0.0%
#
#
# Brain MRI | noise=0.0 | train=1500 | test=500 | classes=4
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100%|██████████| 233M/233M [00:01<00:00, 224MB/s]
# Epoch [1/50] Train Loss: 0.7292 | Train Acc: 92.80% | Test Loss: 0.7057 | Test Acc: 80.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch1.pth]
# Epoch [2/50] Train Loss: 0.4566 | Train Acc: 93.33% | Test Loss: 0.5566 | Test Acc: 80.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch2.pth]
# Epoch [3/50] Train Loss: 0.3087 | Train Acc: 93.33% | Test Loss: 0.4820 | Test Acc: 80.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch3.pth]
# Epoch [4/50] Train Loss: 0.2264 | Train Acc: 93.33% | Test Loss: 0.4828 | Test Acc: 80.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch4.pth]
# Epoch [5/50] Train Loss: 0.1827 | Train Acc: 93.33% | Test Loss: 0.4470 | Test Acc: 80.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch5.pth]
# Epoch [6/50] Train Loss: 0.1567 | Train Acc: 93.33% | Test Loss: 0.4200 | Test Acc: 80.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch6.pth]
# Epoch [7/50] Train Loss: 0.1367 | Train Acc: 93.33% | Test Loss: 0.4299 | Test Acc: 80.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch7.pth]
# Epoch [8/50] Train Loss: 0.1266 | Train Acc: 93.33% | Test Loss: 0.4201 | Test Acc: 80.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch8.pth]
# Epoch [9/50] Train Loss: 0.1117 | Train Acc: 94.47% | Test Loss: 0.4166 | Test Acc: 81.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch9.pth]
# Epoch [10/50] Train Loss: 0.0998 | Train Acc: 96.60% | Test Loss: 0.4166 | Test Acc: 82.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch10.pth]
# Epoch [11/50] Train Loss: 0.0928 | Train Acc: 97.87% | Test Loss: 0.3979 | Test Acc: 84.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch11.pth]
# Epoch [12/50] Train Loss: 0.0860 | Train Acc: 98.73% | Test Loss: 0.3971 | Test Acc: 84.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch12.pth]
# Epoch [13/50] Train Loss: 0.0802 | Train Acc: 98.67% | Test Loss: 0.3608 | Test Acc: 85.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch13.pth]
# Epoch [14/50] Train Loss: 0.0734 | Train Acc: 99.53% | Test Loss: 0.3850 | Test Acc: 86.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch14.pth]
# Epoch [15/50] Train Loss: 0.0684 | Train Acc: 99.60% | Test Loss: 0.3629 | Test Acc: 86.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch15.pth]
# Epoch [16/50] Train Loss: 0.0621 | Train Acc: 100.00% | Test Loss: 0.3626 | Test Acc: 87.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch16.pth]
# Epoch [17/50] Train Loss: 0.0587 | Train Acc: 99.93% | Test Loss: 0.3820 | Test Acc: 86.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch17.pth]
# Epoch [18/50] Train Loss: 0.0562 | Train Acc: 99.73% | Test Loss: 0.3446 | Test Acc: 87.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch18.pth]
# Epoch [19/50] Train Loss: 0.0511 | Train Acc: 99.93% | Test Loss: 0.3447 | Test Acc: 86.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch19.pth]
# Epoch [20/50] Train Loss: 0.0475 | Train Acc: 99.93% | Test Loss: 0.3535 | Test Acc: 86.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch20.pth]
# Epoch [21/50] Train Loss: 0.0446 | Train Acc: 100.00% | Test Loss: 0.3697 | Test Acc: 86.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch21.pth]
# Epoch [22/50] Train Loss: 0.0419 | Train Acc: 100.00% | Test Loss: 0.3552 | Test Acc: 86.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch22.pth]
# Epoch [23/50] Train Loss: 0.0398 | Train Acc: 100.00% | Test Loss: 0.3523 | Test Acc: 85.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch23.pth]
# Epoch [24/50] Train Loss: 0.0367 | Train Acc: 100.00% | Test Loss: 0.3237 | Test Acc: 86.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch24.pth]
# Epoch [25/50] Train Loss: 0.0344 | Train Acc: 100.00% | Test Loss: 0.3466 | Test Acc: 85.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch25.pth]
# Epoch [26/50] Train Loss: 0.0320 | Train Acc: 100.00% | Test Loss: 0.3413 | Test Acc: 84.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch26.pth]
# Epoch [27/50] Train Loss: 0.0299 | Train Acc: 100.00% | Test Loss: 0.3481 | Test Acc: 85.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch27.pth]
# Epoch [28/50] Train Loss: 0.0282 | Train Acc: 100.00% | Test Loss: 0.3563 | Test Acc: 84.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch28.pth]
# Epoch [29/50] Train Loss: 0.0266 | Train Acc: 100.00% | Test Loss: 0.3503 | Test Acc: 84.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch29.pth]
# Epoch [30/50] Train Loss: 0.0251 | Train Acc: 100.00% | Test Loss: 0.3417 | Test Acc: 84.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch30.pth]
# Epoch [31/50] Train Loss: 0.0236 | Train Acc: 100.00% | Test Loss: 0.3664 | Test Acc: 84.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch31.pth]
# Epoch [32/50] Train Loss: 0.0223 | Train Acc: 100.00% | Test Loss: 0.3725 | Test Acc: 84.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch32.pth]
# Epoch [33/50] Train Loss: 0.0212 | Train Acc: 100.00% | Test Loss: 0.3600 | Test Acc: 84.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch33.pth]
# Epoch [34/50] Train Loss: 0.0199 | Train Acc: 100.00% | Test Loss: 0.3476 | Test Acc: 84.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch34.pth]
# Epoch [35/50] Train Loss: 0.0188 | Train Acc: 100.00% | Test Loss: 0.3628 | Test Acc: 84.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch35.pth]
# Epoch [36/50] Train Loss: 0.0177 | Train Acc: 100.00% | Test Loss: 0.3567 | Test Acc: 83.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch36.pth]
# Epoch [37/50] Train Loss: 0.0169 | Train Acc: 100.00% | Test Loss: 0.3821 | Test Acc: 83.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch37.pth]
# Epoch [38/50] Train Loss: 0.0161 | Train Acc: 100.00% | Test Loss: 0.3568 | Test Acc: 83.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch38.pth]
# Epoch [39/50] Train Loss: 0.0153 | Train Acc: 100.00% | Test Loss: 0.3763 | Test Acc: 83.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch39.pth]
# Epoch [40/50] Train Loss: 0.0150 | Train Acc: 100.00% | Test Loss: 0.3673 | Test Acc: 84.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch40.pth]
# Epoch [41/50] Train Loss: 0.0148 | Train Acc: 100.00% | Test Loss: 0.4168 | Test Acc: 83.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch41.pth]
# Epoch [42/50] Train Loss: 0.0135 | Train Acc: 100.00% | Test Loss: 0.3708 | Test Acc: 84.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch42.pth]
# Epoch [43/50] Train Loss: 0.0126 | Train Acc: 100.00% | Test Loss: 0.3653 | Test Acc: 84.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch43.pth]
# Epoch [44/50] Train Loss: 0.0119 | Train Acc: 100.00% | Test Loss: 0.3742 | Test Acc: 84.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch44.pth]
# Epoch [45/50] Train Loss: 0.0112 | Train Acc: 100.00% | Test Loss: 0.3805 | Test Acc: 84.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch45.pth]
# Epoch [46/50] Train Loss: 0.0107 | Train Acc: 100.00% | Test Loss: 0.3769 | Test Acc: 84.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch46.pth]
# Epoch [47/50] Train Loss: 0.0102 | Train Acc: 100.00% | Test Loss: 0.3919 | Test Acc: 83.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch47.pth]
# Epoch [48/50] Train Loss: 0.0098 | Train Acc: 100.00% | Test Loss: 0.4064 | Test Acc: 83.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch48.pth]
# Epoch [49/50] Train Loss: 0.0093 | Train Acc: 100.00% | Test Loss: 0.4121 | Test Acc: 83.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch49.pth]
# Epoch [50/50] Train Loss: 0.0088 | Train Acc: 100.00% | Test Loss: 0.4078 | Test Acc: 83.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_0_epoch50.pth]
#
# Final Metrics | Precision: 0.8444 | Recall: 0.8320 | F1: 0.8370
#
# Brain MRI | noise=0.5%
#
#
# Brain MRI | noise=0.005 | train=1500 | test=500 | classes=4
# Epoch [1/50] Train Loss: 1.0539 | Train Acc: 74.73% | Test Loss: 0.9857 | Test Acc: 79.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch1.pth]
# Epoch [2/50] Train Loss: 0.7483 | Train Acc: 93.33% | Test Loss: 0.7805 | Test Acc: 80.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch2.pth]
# Epoch [3/50] Train Loss: 0.5044 | Train Acc: 93.33% | Test Loss: 0.6577 | Test Acc: 80.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch3.pth]
# Epoch [4/50] Train Loss: 0.3613 | Train Acc: 93.47% | Test Loss: 0.5884 | Test Acc: 81.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch4.pth]
# Epoch [5/50] Train Loss: 0.2719 | Train Acc: 94.00% | Test Loss: 0.5702 | Test Acc: 81.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch5.pth]
# Epoch [6/50] Train Loss: 0.2122 | Train Acc: 94.60% | Test Loss: 0.5298 | Test Acc: 81.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch6.pth]
# Epoch [7/50] Train Loss: 0.1778 | Train Acc: 95.47% | Test Loss: 0.5160 | Test Acc: 81.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch7.pth]
# Epoch [8/50] Train Loss: 0.1540 | Train Acc: 96.33% | Test Loss: 0.4921 | Test Acc: 82.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch8.pth]
# Epoch [9/50] Train Loss: 0.1342 | Train Acc: 96.93% | Test Loss: 0.4482 | Test Acc: 83.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch9.pth]
# Epoch [10/50] Train Loss: 0.1174 | Train Acc: 98.47% | Test Loss: 0.4882 | Test Acc: 85.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch10.pth]
# Epoch [11/50] Train Loss: 0.1067 | Train Acc: 98.47% | Test Loss: 0.4647 | Test Acc: 84.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch11.pth]
# Epoch [12/50] Train Loss: 0.0967 | Train Acc: 99.07% | Test Loss: 0.4925 | Test Acc: 85.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch12.pth]
# Epoch [13/50] Train Loss: 0.0887 | Train Acc: 99.60% | Test Loss: 0.4410 | Test Acc: 87.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch13.pth]
# Epoch [14/50] Train Loss: 0.0820 | Train Acc: 99.53% | Test Loss: 0.4491 | Test Acc: 86.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch14.pth]
# Epoch [15/50] Train Loss: 0.0763 | Train Acc: 99.40% | Test Loss: 0.4373 | Test Acc: 86.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch15.pth]
# Epoch [16/50] Train Loss: 0.0716 | Train Acc: 99.53% | Test Loss: 0.4121 | Test Acc: 87.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch16.pth]
# Epoch [17/50] Train Loss: 0.0673 | Train Acc: 99.53% | Test Loss: 0.4242 | Test Acc: 87.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch17.pth]
# Epoch [18/50] Train Loss: 0.0587 | Train Acc: 99.93% | Test Loss: 0.3714 | Test Acc: 88.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch18.pth]
# Epoch [19/50] Train Loss: 0.0534 | Train Acc: 99.93% | Test Loss: 0.3853 | Test Acc: 88.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch19.pth]
# Epoch [20/50] Train Loss: 0.0488 | Train Acc: 100.00% | Test Loss: 0.3888 | Test Acc: 86.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch20.pth]
# Epoch [21/50] Train Loss: 0.0465 | Train Acc: 100.00% | Test Loss: 0.3812 | Test Acc: 87.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch21.pth]
# Epoch [22/50] Train Loss: 0.0457 | Train Acc: 99.87% | Test Loss: 0.4031 | Test Acc: 87.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch22.pth]
# Epoch [23/50] Train Loss: 0.0412 | Train Acc: 100.00% | Test Loss: 0.3945 | Test Acc: 85.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch23.pth]
# Epoch [24/50] Train Loss: 0.0380 | Train Acc: 100.00% | Test Loss: 0.3835 | Test Acc: 87.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch24.pth]
# Epoch [25/50] Train Loss: 0.0354 | Train Acc: 99.93% | Test Loss: 0.3975 | Test Acc: 87.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch25.pth]
# Epoch [26/50] Train Loss: 0.0332 | Train Acc: 100.00% | Test Loss: 0.3807 | Test Acc: 87.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch26.pth]
# Epoch [27/50] Train Loss: 0.0306 | Train Acc: 100.00% | Test Loss: 0.3977 | Test Acc: 86.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch27.pth]
# Epoch [28/50] Train Loss: 0.0286 | Train Acc: 100.00% | Test Loss: 0.4094 | Test Acc: 87.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch28.pth]
# Epoch [29/50] Train Loss: 0.0270 | Train Acc: 100.00% | Test Loss: 0.3698 | Test Acc: 86.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch29.pth]
# Epoch [30/50] Train Loss: 0.0257 | Train Acc: 100.00% | Test Loss: 0.3791 | Test Acc: 87.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch30.pth]
# Epoch [31/50] Train Loss: 0.0243 | Train Acc: 100.00% | Test Loss: 0.3846 | Test Acc: 87.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch31.pth]
# Epoch [32/50] Train Loss: 0.0240 | Train Acc: 100.00% | Test Loss: 0.4022 | Test Acc: 85.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch32.pth]
# Epoch [33/50] Train Loss: 0.0215 | Train Acc: 100.00% | Test Loss: 0.3854 | Test Acc: 86.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch33.pth]
# Epoch [34/50] Train Loss: 0.0202 | Train Acc: 100.00% | Test Loss: 0.3853 | Test Acc: 86.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch34.pth]
# Epoch [35/50] Train Loss: 0.0200 | Train Acc: 100.00% | Test Loss: 0.4140 | Test Acc: 85.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch35.pth]
# Epoch [36/50] Train Loss: 0.0182 | Train Acc: 100.00% | Test Loss: 0.3884 | Test Acc: 85.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch36.pth]
# Epoch [37/50] Train Loss: 0.0175 | Train Acc: 100.00% | Test Loss: 0.4062 | Test Acc: 86.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch37.pth]
# Epoch [38/50] Train Loss: 0.0165 | Train Acc: 100.00% | Test Loss: 0.4007 | Test Acc: 86.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch38.pth]
# Epoch [39/50] Train Loss: 0.0157 | Train Acc: 100.00% | Test Loss: 0.4060 | Test Acc: 87.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch39.pth]
# Epoch [40/50] Train Loss: 0.0152 | Train Acc: 100.00% | Test Loss: 0.4045 | Test Acc: 86.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch40.pth]
# Epoch [41/50] Train Loss: 0.0143 | Train Acc: 100.00% | Test Loss: 0.4225 | Test Acc: 86.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch41.pth]
# Epoch [42/50] Train Loss: 0.0139 | Train Acc: 100.00% | Test Loss: 0.4182 | Test Acc: 85.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch42.pth]
# Epoch [43/50] Train Loss: 0.0133 | Train Acc: 100.00% | Test Loss: 0.3901 | Test Acc: 86.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch43.pth]
# Epoch [44/50] Train Loss: 0.0124 | Train Acc: 100.00% | Test Loss: 0.4156 | Test Acc: 86.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch44.pth]
# Epoch [45/50] Train Loss: 0.0117 | Train Acc: 100.00% | Test Loss: 0.3917 | Test Acc: 86.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch45.pth]
# Epoch [46/50] Train Loss: 0.0113 | Train Acc: 100.00% | Test Loss: 0.4046 | Test Acc: 85.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch46.pth]
# Epoch [47/50] Train Loss: 0.0107 | Train Acc: 100.00% | Test Loss: 0.4213 | Test Acc: 85.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch47.pth]
# Epoch [48/50] Train Loss: 0.0103 | Train Acc: 100.00% | Test Loss: 0.4045 | Test Acc: 85.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch48.pth]
# Epoch [49/50] Train Loss: 0.0101 | Train Acc: 100.00% | Test Loss: 0.4327 | Test Acc: 84.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch49.pth]
# Epoch [50/50] Train Loss: 0.0093 | Train Acc: 100.00% | Test Loss: 0.4133 | Test Acc: 84.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_005_epoch50.pth]
#
# Final Metrics | Precision: 0.8454 | Recall: 0.8460 | F1: 0.8457
#
# Brain MRI | noise=5.0%
#
#
# Brain MRI | noise=0.05 | train=1500 | test=500 | classes=4
# Epoch [1/50] Train Loss: 0.9948 | Train Acc: 79.60% | Test Loss: 0.9646 | Test Acc: 78.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch1.pth]
# Epoch [2/50] Train Loss: 0.7339 | Train Acc: 93.33% | Test Loss: 0.8295 | Test Acc: 79.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch2.pth]
# Epoch [3/50] Train Loss: 0.5834 | Train Acc: 93.33% | Test Loss: 0.7461 | Test Acc: 80.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch3.pth]
# Epoch [4/50] Train Loss: 0.4618 | Train Acc: 93.33% | Test Loss: 0.6845 | Test Acc: 80.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch4.pth]
# Epoch [5/50] Train Loss: 0.3666 | Train Acc: 93.33% | Test Loss: 0.6319 | Test Acc: 80.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch5.pth]
# Epoch [6/50] Train Loss: 0.2948 | Train Acc: 93.33% | Test Loss: 0.6151 | Test Acc: 80.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch6.pth]
# Epoch [7/50] Train Loss: 0.2362 | Train Acc: 93.53% | Test Loss: 0.5355 | Test Acc: 80.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch7.pth]
# Epoch [8/50] Train Loss: 0.1943 | Train Acc: 93.67% | Test Loss: 0.5143 | Test Acc: 81.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch8.pth]
# Epoch [9/50] Train Loss: 0.1651 | Train Acc: 94.47% | Test Loss: 0.5355 | Test Acc: 82.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch9.pth]
# Epoch [10/50] Train Loss: 0.1444 | Train Acc: 95.07% | Test Loss: 0.5133 | Test Acc: 82.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch10.pth]
# Epoch [11/50] Train Loss: 0.1243 | Train Acc: 96.60% | Test Loss: 0.4943 | Test Acc: 83.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch11.pth]
# Epoch [12/50] Train Loss: 0.1131 | Train Acc: 97.07% | Test Loss: 0.5004 | Test Acc: 85.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch12.pth]
# Epoch [13/50] Train Loss: 0.1077 | Train Acc: 97.07% | Test Loss: 0.4703 | Test Acc: 85.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch13.pth]
# Epoch [14/50] Train Loss: 0.0952 | Train Acc: 97.60% | Test Loss: 0.4327 | Test Acc: 85.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch14.pth]
# Epoch [15/50] Train Loss: 0.0948 | Train Acc: 97.93% | Test Loss: 0.4998 | Test Acc: 86.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch15.pth]
# Epoch [16/50] Train Loss: 0.0829 | Train Acc: 98.73% | Test Loss: 0.4699 | Test Acc: 87.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch16.pth]
# Epoch [17/50] Train Loss: 0.0756 | Train Acc: 99.07% | Test Loss: 0.4267 | Test Acc: 87.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch17.pth]
# Epoch [18/50] Train Loss: 0.0689 | Train Acc: 99.33% | Test Loss: 0.5225 | Test Acc: 86.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch18.pth]
# Epoch [19/50] Train Loss: 0.0652 | Train Acc: 99.40% | Test Loss: 0.4657 | Test Acc: 87.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch19.pth]
# Epoch [20/50] Train Loss: 0.0619 | Train Acc: 99.53% | Test Loss: 0.4189 | Test Acc: 89.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch20.pth]
# Epoch [21/50] Train Loss: 0.0610 | Train Acc: 99.47% | Test Loss: 0.4844 | Test Acc: 87.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch21.pth]
# Epoch [22/50] Train Loss: 0.0528 | Train Acc: 99.67% | Test Loss: 0.4333 | Test Acc: 87.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch22.pth]
# Epoch [23/50] Train Loss: 0.0502 | Train Acc: 99.87% | Test Loss: 0.4410 | Test Acc: 87.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch23.pth]
# Epoch [24/50] Train Loss: 0.0444 | Train Acc: 99.87% | Test Loss: 0.4368 | Test Acc: 88.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch24.pth]
# Epoch [25/50] Train Loss: 0.0431 | Train Acc: 99.87% | Test Loss: 0.4704 | Test Acc: 87.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch25.pth]
# Epoch [26/50] Train Loss: 0.0399 | Train Acc: 99.93% | Test Loss: 0.4438 | Test Acc: 87.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch26.pth]
# Epoch [27/50] Train Loss: 0.0358 | Train Acc: 100.00% | Test Loss: 0.4090 | Test Acc: 88.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch27.pth]
# Epoch [28/50] Train Loss: 0.0359 | Train Acc: 99.93% | Test Loss: 0.4271 | Test Acc: 87.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch28.pth]
# Epoch [29/50] Train Loss: 0.0331 | Train Acc: 100.00% | Test Loss: 0.4594 | Test Acc: 86.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch29.pth]
# Epoch [30/50] Train Loss: 0.0323 | Train Acc: 99.93% | Test Loss: 0.4195 | Test Acc: 88.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch30.pth]
# Epoch [31/50] Train Loss: 0.0292 | Train Acc: 100.00% | Test Loss: 0.4523 | Test Acc: 87.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch31.pth]
# Epoch [32/50] Train Loss: 0.0287 | Train Acc: 100.00% | Test Loss: 0.3816 | Test Acc: 88.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch32.pth]
# Epoch [33/50] Train Loss: 0.0258 | Train Acc: 100.00% | Test Loss: 0.4559 | Test Acc: 87.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch33.pth]
# Epoch [34/50] Train Loss: 0.0248 | Train Acc: 100.00% | Test Loss: 0.4287 | Test Acc: 88.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch34.pth]
# Epoch [35/50] Train Loss: 0.0226 | Train Acc: 100.00% | Test Loss: 0.4412 | Test Acc: 88.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch35.pth]
# Epoch [36/50] Train Loss: 0.0231 | Train Acc: 100.00% | Test Loss: 0.4415 | Test Acc: 88.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch36.pth]
# Epoch [37/50] Train Loss: 0.0215 | Train Acc: 100.00% | Test Loss: 0.4148 | Test Acc: 87.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch37.pth]
# Epoch [38/50] Train Loss: 0.0199 | Train Acc: 100.00% | Test Loss: 0.4144 | Test Acc: 87.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch38.pth]
# Epoch [39/50] Train Loss: 0.0183 | Train Acc: 100.00% | Test Loss: 0.4364 | Test Acc: 87.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch39.pth]
# Epoch [40/50] Train Loss: 0.0181 | Train Acc: 100.00% | Test Loss: 0.4204 | Test Acc: 87.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch40.pth]
# Epoch [41/50] Train Loss: 0.0179 | Train Acc: 100.00% | Test Loss: 0.4176 | Test Acc: 88.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch41.pth]
# Epoch [42/50] Train Loss: 0.0164 | Train Acc: 100.00% | Test Loss: 0.4303 | Test Acc: 88.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch42.pth]
# Epoch [43/50] Train Loss: 0.0154 | Train Acc: 100.00% | Test Loss: 0.4582 | Test Acc: 87.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch43.pth]
# Epoch [44/50] Train Loss: 0.0159 | Train Acc: 100.00% | Test Loss: 0.4266 | Test Acc: 88.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch44.pth]
# Epoch [45/50] Train Loss: 0.0155 | Train Acc: 99.93% | Test Loss: 0.5016 | Test Acc: 86.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch45.pth]
# Epoch [46/50] Train Loss: 0.0227 | Train Acc: 99.67% | Test Loss: 0.4543 | Test Acc: 87.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch46.pth]
# Epoch [47/50] Train Loss: 0.0229 | Train Acc: 99.73% | Test Loss: 0.4603 | Test Acc: 86.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch47.pth]
# Epoch [48/50] Train Loss: 0.0250 | Train Acc: 99.73% | Test Loss: 0.4806 | Test Acc: 86.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch48.pth]
# Epoch [49/50] Train Loss: 0.0209 | Train Acc: 99.87% | Test Loss: 0.3934 | Test Acc: 88.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch49.pth]
# Epoch [50/50] Train Loss: 0.0164 | Train Acc: 99.93% | Test Loss: 0.3490 | Test Acc: 87.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_05_epoch50.pth]
#
# Final Metrics | Precision: 0.8702 | Recall: 0.8760 | F1: 0.8718
#
# Brain MRI | noise=10.0%
#
#
# Brain MRI | noise=0.1 | train=1500 | test=500 | classes=4
# Epoch [2/50] Train Loss: 0.6945 | Train Acc: 93.33% | Test Loss: 0.7285 | Test Acc: 80.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch2.pth]
# Epoch [3/50] Train Loss: 0.5054 | Train Acc: 93.33% | Test Loss: 0.6253 | Test Acc: 80.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch3.pth]
# Epoch [4/50] Train Loss: 0.3823 | Train Acc: 93.33% | Test Loss: 0.5678 | Test Acc: 80.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch4.pth]
# Epoch [5/50] Train Loss: 0.3058 | Train Acc: 93.33% | Test Loss: 0.5233 | Test Acc: 80.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch5.pth]
# Epoch [6/50] Train Loss: 0.2487 | Train Acc: 93.33% | Test Loss: 0.4886 | Test Acc: 80.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch6.pth]
# Epoch [7/50] Train Loss: 0.2116 | Train Acc: 93.33% | Test Loss: 0.4726 | Test Acc: 80.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch7.pth]
# Epoch [8/50] Train Loss: 0.1808 | Train Acc: 93.33% | Test Loss: 0.4602 | Test Acc: 80.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch8.pth]
# Epoch [9/50] Train Loss: 0.1571 | Train Acc: 93.33% | Test Loss: 0.4573 | Test Acc: 80.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch9.pth]
# Epoch [10/50] Train Loss: 0.1428 | Train Acc: 93.73% | Test Loss: 0.4692 | Test Acc: 80.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch10.pth]
# Epoch [11/50] Train Loss: 0.1261 | Train Acc: 94.67% | Test Loss: 0.4143 | Test Acc: 83.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch11.pth]
# Epoch [12/50] Train Loss: 0.1173 | Train Acc: 95.67% | Test Loss: 0.4273 | Test Acc: 81.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch12.pth]
# Epoch [13/50] Train Loss: 0.1074 | Train Acc: 96.87% | Test Loss: 0.4233 | Test Acc: 84.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch13.pth]
# Epoch [14/50] Train Loss: 0.0973 | Train Acc: 97.67% | Test Loss: 0.4368 | Test Acc: 85.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch14.pth]
# Epoch [15/50] Train Loss: 0.0896 | Train Acc: 98.53% | Test Loss: 0.4171 | Test Acc: 84.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch15.pth]
# Epoch [16/50] Train Loss: 0.0826 | Train Acc: 99.07% | Test Loss: 0.4129 | Test Acc: 85.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch16.pth]
# Epoch [17/50] Train Loss: 0.0770 | Train Acc: 99.13% | Test Loss: 0.4130 | Test Acc: 86.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch17.pth]
# Epoch [18/50] Train Loss: 0.0739 | Train Acc: 99.00% | Test Loss: 0.3782 | Test Acc: 87.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch18.pth]
# Epoch [19/50] Train Loss: 0.0695 | Train Acc: 99.60% | Test Loss: 0.4072 | Test Acc: 85.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch19.pth]
# Epoch [20/50] Train Loss: 0.0647 | Train Acc: 99.47% | Test Loss: 0.4015 | Test Acc: 87.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch20.pth]
# Epoch [21/50] Train Loss: 0.0637 | Train Acc: 99.60% | Test Loss: 0.4130 | Test Acc: 87.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch21.pth]
# Epoch [22/50] Train Loss: 0.0602 | Train Acc: 99.33% | Test Loss: 0.4474 | Test Acc: 86.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch22.pth]
# Epoch [23/50] Train Loss: 0.0551 | Train Acc: 99.40% | Test Loss: 0.3846 | Test Acc: 87.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch23.pth]
# Epoch [24/50] Train Loss: 0.0488 | Train Acc: 99.80% | Test Loss: 0.4082 | Test Acc: 86.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch24.pth]
# Epoch [25/50] Train Loss: 0.0447 | Train Acc: 99.93% | Test Loss: 0.3800 | Test Acc: 87.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch25.pth]
# Epoch [26/50] Train Loss: 0.0408 | Train Acc: 99.93% | Test Loss: 0.3777 | Test Acc: 88.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch26.pth]
# Epoch [27/50] Train Loss: 0.0371 | Train Acc: 100.00% | Test Loss: 0.4129 | Test Acc: 87.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch27.pth]
# Epoch [28/50] Train Loss: 0.0357 | Train Acc: 99.93% | Test Loss: 0.3775 | Test Acc: 88.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch28.pth]
# Epoch [29/50] Train Loss: 0.0355 | Train Acc: 99.87% | Test Loss: 0.4072 | Test Acc: 86.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch29.pth]
# Epoch [30/50] Train Loss: 0.0333 | Train Acc: 99.73% | Test Loss: 0.3817 | Test Acc: 87.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch30.pth]
# Epoch [31/50] Train Loss: 0.0311 | Train Acc: 99.93% | Test Loss: 0.4431 | Test Acc: 86.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch31.pth]
# Epoch [32/50] Train Loss: 0.0286 | Train Acc: 99.93% | Test Loss: 0.4364 | Test Acc: 87.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch32.pth]
# Epoch [33/50] Train Loss: 0.0281 | Train Acc: 99.87% | Test Loss: 0.4040 | Test Acc: 87.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch33.pth]
# Epoch [34/50] Train Loss: 0.0259 | Train Acc: 99.87% | Test Loss: 0.4403 | Test Acc: 86.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch34.pth]
# Epoch [35/50] Train Loss: 0.0235 | Train Acc: 99.93% | Test Loss: 0.4034 | Test Acc: 87.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch35.pth]
# Epoch [36/50] Train Loss: 0.0219 | Train Acc: 100.00% | Test Loss: 0.4218 | Test Acc: 86.80%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch36.pth]
# Epoch [37/50] Train Loss: 0.0210 | Train Acc: 99.93% | Test Loss: 0.3932 | Test Acc: 86.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch37.pth]
# Epoch [38/50] Train Loss: 0.0196 | Train Acc: 100.00% | Test Loss: 0.4204 | Test Acc: 86.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch38.pth]
# Epoch [39/50] Train Loss: 0.0191 | Train Acc: 100.00% | Test Loss: 0.4507 | Test Acc: 85.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch39.pth]
# Epoch [40/50] Train Loss: 0.0163 | Train Acc: 100.00% | Test Loss: 0.4400 | Test Acc: 86.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch40.pth]
# Epoch [41/50] Train Loss: 0.0159 | Train Acc: 100.00% | Test Loss: 0.4490 | Test Acc: 86.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch41.pth]
# Epoch [42/50] Train Loss: 0.0160 | Train Acc: 100.00% | Test Loss: 0.4011 | Test Acc: 86.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch42.pth]
# Epoch [43/50] Train Loss: 0.0156 | Train Acc: 100.00% | Test Loss: 0.4296 | Test Acc: 86.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch43.pth]
# Epoch [44/50] Train Loss: 0.0147 | Train Acc: 99.93% | Test Loss: 0.4451 | Test Acc: 86.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch44.pth]
# Epoch [45/50] Train Loss: 0.0130 | Train Acc: 100.00% | Test Loss: 0.4327 | Test Acc: 86.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch45.pth]
# Epoch [46/50] Train Loss: 0.0128 | Train Acc: 100.00% | Test Loss: 0.4262 | Test Acc: 87.40%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch46.pth]
# Epoch [47/50] Train Loss: 0.0125 | Train Acc: 100.00% | Test Loss: 0.4371 | Test Acc: 87.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch47.pth]
# Epoch [48/50] Train Loss: 0.0116 | Train Acc: 100.00% | Test Loss: 0.4128 | Test Acc: 87.20%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch48.pth]
# Epoch [49/50] Train Loss: 0.0109 | Train Acc: 100.00% | Test Loss: 0.4467 | Test Acc: 86.60%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch49.pth]
# Epoch [50/50] Train Loss: 0.0117 | Train Acc: 100.00% | Test Loss: 0.4657 | Test Acc: 86.00%
#   [Saved checkpoint: /kaggle/working/brain_checkpoints/ckpt_noise0_1_epoch50.pth]
#
# Final Metrics | Precision: 0.8496 | Recall: 0.8600 | F1: 0.8476
#
# [All results saved to /kaggle/working/brain_checkpoints]
#
# All experiments complete.

# %%
def plot_metrics(results):
    epochs       = list(range(1, N_EPOCHS + 1))
    noise_labels = {0.0: "0% noise", 0.005: "0.5% noise", 0.05: "5% noise", 0.10: "10% noise"}
    colors       = {0.0: "#2196F3",  0.005: "#4CAF50",    0.05: "#FF9800",  0.10: "#F44336"}

    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    fig.suptitle("Quantum AlexNet: Brain Tumour MRI", fontsize=14, fontweight="bold")
    ax_loss, ax_acc = axes

    for noise, history in results.items():
        c = colors[noise]; l = noise_labels[noise]
        ep = list(range(1, len(history["train_loss"]) + 1))
        ax_loss.plot(ep, history["train_loss"], color=c, ls="-",  label=f"{l} (train)")
        ax_loss.plot(ep, history["test_loss"],  color=c, ls="--", label=f"{l} (test)")
        ax_acc.plot(ep,  [a*100 for a in history["train_acc"]], color=c, ls="-",  label=f"{l} (train)")
        ax_acc.plot(ep,  [a*100 for a in history["test_acc"]],  color=c, ls="--", label=f"{l} (test)")

    for ax, ylabel, title in zip(
        [ax_loss, ax_acc],
        ["Cross-Entropy Loss", "Accuracy (%)"],
        ["Loss Curves", "Accuracy Curves"]
    ):
        ax.set_xlabel("Epoch"); ax.set_ylabel(ylabel); ax.set_title(title)
        ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
        ax.legend(fontsize=8); ax.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(os.path.join(SAVE_DIR, "quantum_alexnet_brain.png"), dpi=150, bbox_inches="tight")
    plt.show()

# %%
def plot_confusion_matrices(results, class_names):
    noise_labels = {0.0: "0%", 0.005: "0.5%", 0.05: "5%", 0.10: "10%"}
    fig, axes = plt.subplots(1, 4, figsize=(24, 5))
    fig.suptitle("Quantum AlexNet: Brain Tumour MRI Confusion Matrices", fontsize=14, fontweight="bold")

    for ax, (noise, history) in zip(axes, results.items()):
        sns.heatmap(
            history["cm"], annot=True, fmt="d", cmap="Blues",
            xticklabels=class_names, yticklabels=class_names, ax=ax
        )
        ax.set_title(f"Noise: {noise_labels[noise]}")
        ax.set_xlabel("Predicted")
        ax.set_ylabel("True")

    plt.tight_layout()
    plt.savefig(os.path.join(SAVE_DIR, "quantum_alexnet_brain_cm.png"), dpi=150, bbox_inches="tight")
    plt.show()

# %%
def print_summary(results):
    noise_labels = {0.0: "0%", 0.005: "0.5%", 0.05: "5%", 0.10: "10%"}
    header = f"{'Noise':>8} {'Test Acc':>10} {'Test Loss':>12} {'Precision':>12} {'Recall':>10} {'F1':>10}"
    print("\nBrain Tumour MRI: Results")
    print("\n")
    print(header)
    print("\n")
    for noise, history in results.items():
        print(
            f"{noise_labels[noise]:>8} "
            f"{history['test_acc'][-1]*100:>9.2f}% "
            f"{history['test_loss'][-1]:>12.4f} "
            f"{history['precision']:>12.4f} "
            f"{history['recall']:>10.4f} "
            f"{history['f1']:>10.4f}"
        )
    print("\n")

brain_classes = ["glioma", "meningioma", "notumor", "pituitary"]
plot_metrics(results)
plot_confusion_matrices(results, brain_classes)
print_summary(results)
# Out:
# Brain Tumour MRI: Results
#
#
#    Noise   Test Acc    Test Loss    Precision     Recall         F1
#
#
#       0%     83.20%       0.4078       0.8444     0.8320     0.8370
#     0.5%     84.60%       0.4133       0.8454     0.8460     0.8457
#       5%     87.60%       0.3490       0.8702     0.8760     0.8718
#      10%     86.00%       0.4657       0.8496     0.8600     0.8476
