# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms, models
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import json

# %%
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {DEVICE}")
# Out:
# Using device: cuda

# %%
N_EPOCHS      = 50
BATCH_SIZE    = 32
LEARNING_RATE = 0.001
TRAIN_SUBSET  = 1500
TEST_SUBSET   = 500

NOISE_LEVELS = [0.0, 0.005, 0.05, 0.10]

SAVE_DIR = "./mnist_classical_checkpoints"
os.makedirs(SAVE_DIR, exist_ok=True)

# %%
class ClassicalAlexNet(nn.Module):
    def __init__(self, n_classes=10):
        super(ClassicalAlexNet, self).__init__()
        alexnet = models.alexnet(weights=models.AlexNet_Weights.DEFAULT)
        self.features = alexnet.features
        for param in self.features.parameters():
            param.requires_grad = False
        self.avgpool = alexnet.avgpool
        self.flatten = nn.Flatten()
        self.dense1 = nn.Linear(9216, 512)
        self.bn1    = nn.BatchNorm1d(512)
        self.act1   = nn.LeakyReLU(0.1)
        self.dense2 = nn.Linear(512, 128)
        self.bn2    = nn.BatchNorm1d(128)
        self.act2   = nn.LeakyReLU(0.1)
        self.classifier = nn.Linear(128, n_classes)

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = self.flatten(x)
        x = self.act1(self.bn1(self.dense1(x)))
        x = self.act2(self.bn2(self.dense2(x)))
        x = self.classifier(x)
        return x

# %%
class AddGaussianNoise:
    def __init__(self, std=0.0):
        self.std = std
    def __call__(self, tensor):
        if self.std == 0.0:
            return tensor
        return torch.clamp(tensor + torch.randn_like(tensor) * self.std, 0.0, 1.0)

# %%
def build_loaders_mnist(noise_std=0.0):
    noise_step = [AddGaussianNoise(std=noise_std)] if noise_std > 0.0 else []
    tf = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Lambda(lambda x: x.repeat(3, 1, 1)),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225]),
    ] + noise_step)
    train_full = datasets.MNIST(root="./data", train=True,  download=True, transform=tf)
    test_full  = datasets.MNIST(root="./data", train=False, download=True, transform=tf)
    train_loader = DataLoader(Subset(train_full, list(range(TRAIN_SUBSET))),
                              batch_size=BATCH_SIZE, shuffle=True)
    test_loader  = DataLoader(Subset(test_full,  list(range(TEST_SUBSET))),
                              batch_size=BATCH_SIZE, shuffle=False)
    print(f"MNIST | noise={noise_std} | train={TRAIN_SUBSET} | test={TEST_SUBSET}")
    return train_loader, test_loader

# %%
def train_one_epoch(model, loader, criterion, optimizer):
    model.train()
    total_loss, correct, total = 0.0, 0, 0
    for images, labels in loader:
        images, labels = images.to(DEVICE), labels.to(DEVICE)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * images.size(0)
        correct    += (outputs.argmax(dim=1) == labels).sum().item()
        total      += images.size(0)
    return total_loss / total, correct / total

def evaluate(model, loader, criterion):
    model.eval()
    total_loss, correct, total = 0.0, 0, 0
    all_preds, all_labels = [], []
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            loss = criterion(outputs, labels)
            total_loss += loss.item() * images.size(0)
            preds = outputs.argmax(dim=1)
            correct += (preds == labels).sum().item()
            total   += images.size(0)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    return total_loss / total, correct / total, all_preds, all_labels

def save_checkpoint(noise_std, epoch, model, optimizer, history):
    noise_tag = str(noise_std).replace(".", "_")
    path = os.path.join(SAVE_DIR, f"ckpt_noise{noise_tag}_epoch{epoch}.pth")
    torch.save({
        "epoch":                epoch,
        "model_state_dict":     model.state_dict(),
        "optimizer_state_dict": optimizer.state_dict(),
        "history":              history,
    }, path)
    json_path = os.path.join(SAVE_DIR, f"history_noise{noise_tag}.json")
    json_history = {k: v for k, v in history.items() if k != "cm"}
    with open(json_path, "w") as f:
        json.dump(json_history, f)
    print(f"  [Saved checkpoint: {path}]")

def load_latest_checkpoint(noise_std, model, optimizer):
    noise_tag = str(noise_std).replace(".", "_")
    files = [
        f for f in os.listdir(SAVE_DIR)
        if f.startswith(f"ckpt_noise{noise_tag}_epoch") and f.endswith(".pth")
    ]
    if not files:
        return 0, {"train_loss": [], "train_acc": [], "test_loss": [], "test_acc": []}
    latest = sorted(files, key=lambda x: int(x.split("_epoch")[1].replace(".pth", "")))[-1]
    path = os.path.join(SAVE_DIR, latest)
    checkpoint = torch.load(path, map_location=DEVICE)
    model.load_state_dict(checkpoint["model_state_dict"])
    optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
    print(f"  [Resumed from checkpoint: {path}]")
    return checkpoint["epoch"], checkpoint["history"]

def save_final_results(results):
    for noise, history in results.items():
        noise_tag = str(noise).replace(".", "_")
        if "cm" in history:
            np.save(os.path.join(SAVE_DIR, f"cm_noise{noise_tag}.npy"), history["cm"])
    json_results = {}
    for noise, history in results.items():
        noise_tag = str(noise).replace(".", "_")
        json_results[noise_tag] = {k: v for k, v in history.items() if k != "cm"}
    with open(os.path.join(SAVE_DIR, "all_results.json"), "w") as f:
        json.dump(json_results, f)
    print(f"\n[All results saved to {SAVE_DIR}]")

# %%
def run_experiment_mnist(noise_std):
    print(f"\nMNIST Classical | noise={noise_std * 100:.1f}%")
    print("\n")
    train_loader, test_loader = build_loaders_mnist(noise_std=noise_std)
    model     = ClassicalAlexNet(n_classes=10).to(DEVICE)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(
        filter(lambda p: p.requires_grad, model.parameters()),
        lr=LEARNING_RATE
    )
    start_epoch, history = load_latest_checkpoint(noise_std, model, optimizer)
    if start_epoch > 0:
        print(f"  [Resuming from epoch {start_epoch + 1}]")
    for epoch in range(start_epoch + 1, N_EPOCHS + 1):
        tr_loss, tr_acc = train_one_epoch(model, train_loader, criterion, optimizer)
        te_loss, te_acc, preds, labels = evaluate(model, test_loader, criterion)
        history["train_loss"].append(tr_loss)
        history["train_acc"].append(tr_acc)
        history["test_loss"].append(te_loss)
        history["test_acc"].append(te_acc)
        print(f"Epoch [{epoch}/{N_EPOCHS}] "
              f"Train Loss: {tr_loss:.4f} | Train Acc: {tr_acc*100:.2f}% | "
              f"Test Loss: {te_loss:.4f} | Test Acc: {te_acc*100:.2f}%")
        save_checkpoint(noise_std, epoch, model, optimizer, history)
    precision = precision_score(labels, preds, average="weighted", zero_division=0)
    recall    = recall_score(labels, preds, average="weighted", zero_division=0)
    f1        = f1_score(labels, preds, average="weighted", zero_division=0)
    cm        = confusion_matrix(labels, preds)
    history["precision"] = precision
    history["recall"]    = recall
    history["f1"]        = f1
    history["cm"]        = cm
    print(f"\nFinal Metrics | Precision: {precision:.4f} | Recall: {recall:.4f} | F1: {f1:.4f}")
    return history

# %%
results = {}
for noise in NOISE_LEVELS:
    results[noise] = run_experiment_mnist(noise)

save_final_results(results)
print("\nAll experiments complete.")
# Out:
# MNIST Classical | noise=0.0%
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 37.5MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 1.15MB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 10.4MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 12.0MB/s]
# MNIST | noise=0.0 | train=1500 | test=500
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100%|██████████| 233M/233M [00:01<00:00, 167MB/s]
# Epoch [1/50] Train Loss: 0.4635 | Train Acc: 91.40% | Test Loss: 0.1524 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch1.pth]
# Epoch [2/50] Train Loss: 0.0855 | Train Acc: 99.13% | Test Loss: 0.1034 | Test Acc: 97.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch2.pth]
# Epoch [3/50] Train Loss: 0.0318 | Train Acc: 99.80% | Test Loss: 0.0729 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch3.pth]
# Epoch [4/50] Train Loss: 0.0166 | Train Acc: 100.00% | Test Loss: 0.0636 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch4.pth]
# Epoch [5/50] Train Loss: 0.0090 | Train Acc: 100.00% | Test Loss: 0.0525 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch5.pth]
# Epoch [6/50] Train Loss: 0.0061 | Train Acc: 100.00% | Test Loss: 0.0504 | Test Acc: 99.00%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch6.pth]
# Epoch [7/50] Train Loss: 0.0053 | Train Acc: 100.00% | Test Loss: 0.0559 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch7.pth]
# Epoch [8/50] Train Loss: 0.0043 | Train Acc: 100.00% | Test Loss: 0.0538 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch8.pth]
# Epoch [9/50] Train Loss: 0.0029 | Train Acc: 100.00% | Test Loss: 0.0483 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch9.pth]
# Epoch [10/50] Train Loss: 0.0027 | Train Acc: 100.00% | Test Loss: 0.0471 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch10.pth]
# Epoch [11/50] Train Loss: 0.0021 | Train Acc: 100.00% | Test Loss: 0.0428 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch11.pth]
# Epoch [12/50] Train Loss: 0.0019 | Train Acc: 100.00% | Test Loss: 0.0439 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch12.pth]
# Epoch [13/50] Train Loss: 0.0015 | Train Acc: 100.00% | Test Loss: 0.0439 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch13.pth]
# Epoch [14/50] Train Loss: 0.0014 | Train Acc: 100.00% | Test Loss: 0.0421 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch14.pth]
# Epoch [15/50] Train Loss: 0.0011 | Train Acc: 100.00% | Test Loss: 0.0425 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch15.pth]
# Epoch [16/50] Train Loss: 0.0011 | Train Acc: 100.00% | Test Loss: 0.0418 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch16.pth]
# Epoch [17/50] Train Loss: 0.0009 | Train Acc: 100.00% | Test Loss: 0.0390 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch17.pth]
# Epoch [18/50] Train Loss: 0.0010 | Train Acc: 100.00% | Test Loss: 0.0380 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch18.pth]
# Epoch [19/50] Train Loss: 0.0009 | Train Acc: 100.00% | Test Loss: 0.0375 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch19.pth]
# Epoch [20/50] Train Loss: 0.0008 | Train Acc: 100.00% | Test Loss: 0.0414 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch20.pth]
# Epoch [21/50] Train Loss: 0.0007 | Train Acc: 100.00% | Test Loss: 0.0407 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch21.pth]
# Epoch [22/50] Train Loss: 0.0006 | Train Acc: 100.00% | Test Loss: 0.0383 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch22.pth]
# Epoch [23/50] Train Loss: 0.0005 | Train Acc: 100.00% | Test Loss: 0.0403 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch23.pth]
# Epoch [24/50] Train Loss: 0.0005 | Train Acc: 100.00% | Test Loss: 0.0376 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch24.pth]
# Epoch [25/50] Train Loss: 0.0005 | Train Acc: 100.00% | Test Loss: 0.0390 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch25.pth]
# Epoch [26/50] Train Loss: 0.0005 | Train Acc: 100.00% | Test Loss: 0.0393 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch26.pth]
# Epoch [27/50] Train Loss: 0.0005 | Train Acc: 100.00% | Test Loss: 0.0393 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch27.pth]
# Epoch [28/50] Train Loss: 0.0004 | Train Acc: 100.00% | Test Loss: 0.0427 | Test Acc: 98.00%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch28.pth]
# Epoch [29/50] Train Loss: 0.0005 | Train Acc: 100.00% | Test Loss: 0.0457 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch29.pth]
# Epoch [30/50] Train Loss: 0.0003 | Train Acc: 100.00% | Test Loss: 0.0424 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch30.pth]
# Epoch [31/50] Train Loss: 0.0004 | Train Acc: 100.00% | Test Loss: 0.0378 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch31.pth]
# Epoch [32/50] Train Loss: 0.0003 | Train Acc: 100.00% | Test Loss: 0.0397 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch32.pth]
# Epoch [33/50] Train Loss: 0.0003 | Train Acc: 100.00% | Test Loss: 0.0394 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch33.pth]
# Epoch [34/50] Train Loss: 0.0004 | Train Acc: 100.00% | Test Loss: 0.0439 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch34.pth]
# Epoch [35/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0396 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch35.pth]
# Epoch [36/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0397 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch36.pth]
# Epoch [37/50] Train Loss: 0.0003 | Train Acc: 100.00% | Test Loss: 0.0373 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch37.pth]
# Epoch [38/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0378 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch38.pth]
# Epoch [39/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0380 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch39.pth]
# Epoch [40/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0379 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch40.pth]
# Epoch [41/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0367 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch41.pth]
# Epoch [42/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0417 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch42.pth]
# Epoch [43/50] Train Loss: 0.0001 | Train Acc: 100.00% | Test Loss: 0.0404 | Test Acc: 99.00%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch43.pth]
# Epoch [44/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0352 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch44.pth]
# Epoch [45/50] Train Loss: 0.0001 | Train Acc: 100.00% | Test Loss: 0.0418 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch45.pth]
# Epoch [46/50] Train Loss: 0.0001 | Train Acc: 100.00% | Test Loss: 0.0384 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch46.pth]
# Epoch [47/50] Train Loss: 0.0001 | Train Acc: 100.00% | Test Loss: 0.0363 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch47.pth]
# Epoch [48/50] Train Loss: 0.0001 | Train Acc: 100.00% | Test Loss: 0.0373 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch48.pth]
# Epoch [49/50] Train Loss: 0.0001 | Train Acc: 100.00% | Test Loss: 0.0371 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch49.pth]
# Epoch [50/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0404 | Test Acc: 99.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_0_epoch50.pth]
#
# Final Metrics | Precision: 0.9921 | Recall: 0.9920 | F1: 0.9920
#
# MNIST Classical | noise=0.5%
#
#
# MNIST | noise=0.005 | train=1500 | test=500
# Epoch [1/50] Train Loss: 0.4493 | Train Acc: 91.67% | Test Loss: 0.1493 | Test Acc: 97.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch1.pth]
# Epoch [2/50] Train Loss: 0.0989 | Train Acc: 98.60% | Test Loss: 0.1146 | Test Acc: 97.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch2.pth]
# Epoch [3/50] Train Loss: 0.0343 | Train Acc: 99.80% | Test Loss: 0.0730 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch3.pth]
# Epoch [4/50] Train Loss: 0.0183 | Train Acc: 100.00% | Test Loss: 0.0649 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch4.pth]
# Epoch [5/50] Train Loss: 0.0095 | Train Acc: 100.00% | Test Loss: 0.0571 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch5.pth]
# Epoch [6/50] Train Loss: 0.0110 | Train Acc: 99.87% | Test Loss: 0.0719 | Test Acc: 97.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch6.pth]
# Epoch [7/50] Train Loss: 0.0077 | Train Acc: 100.00% | Test Loss: 0.0540 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch7.pth]
# Epoch [8/50] Train Loss: 0.0044 | Train Acc: 100.00% | Test Loss: 0.0523 | Test Acc: 98.00%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch8.pth]
# Epoch [9/50] Train Loss: 0.0035 | Train Acc: 100.00% | Test Loss: 0.0533 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch9.pth]
# Epoch [10/50] Train Loss: 0.0023 | Train Acc: 100.00% | Test Loss: 0.0530 | Test Acc: 98.00%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch10.pth]
# Epoch [11/50] Train Loss: 0.0022 | Train Acc: 100.00% | Test Loss: 0.0478 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch11.pth]
# Epoch [12/50] Train Loss: 0.0021 | Train Acc: 100.00% | Test Loss: 0.0510 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch12.pth]
# Epoch [13/50] Train Loss: 0.0017 | Train Acc: 100.00% | Test Loss: 0.0463 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch13.pth]
# Epoch [14/50] Train Loss: 0.0016 | Train Acc: 100.00% | Test Loss: 0.0480 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch14.pth]
# Epoch [15/50] Train Loss: 0.0016 | Train Acc: 100.00% | Test Loss: 0.0478 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch15.pth]
# Epoch [16/50] Train Loss: 0.0010 | Train Acc: 100.00% | Test Loss: 0.0445 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch16.pth]
# Epoch [17/50] Train Loss: 0.0011 | Train Acc: 100.00% | Test Loss: 0.0441 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch17.pth]
# Epoch [18/50] Train Loss: 0.0009 | Train Acc: 100.00% | Test Loss: 0.0392 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch18.pth]
# Epoch [19/50] Train Loss: 0.0007 | Train Acc: 100.00% | Test Loss: 0.0409 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch19.pth]
# Epoch [20/50] Train Loss: 0.0007 | Train Acc: 100.00% | Test Loss: 0.0435 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch20.pth]
# Epoch [21/50] Train Loss: 0.0115 | Train Acc: 99.53% | Test Loss: 0.3942 | Test Acc: 87.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch21.pth]
# Epoch [22/50] Train Loss: 0.0493 | Train Acc: 98.53% | Test Loss: 0.1815 | Test Acc: 94.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch22.pth]
# Epoch [23/50] Train Loss: 0.0501 | Train Acc: 98.73% | Test Loss: 0.1418 | Test Acc: 96.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch23.pth]
# Epoch [24/50] Train Loss: 0.0210 | Train Acc: 99.40% | Test Loss: 0.0688 | Test Acc: 97.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch24.pth]
# Epoch [25/50] Train Loss: 0.0099 | Train Acc: 99.80% | Test Loss: 0.0724 | Test Acc: 97.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch25.pth]
# Epoch [26/50] Train Loss: 0.0032 | Train Acc: 100.00% | Test Loss: 0.0735 | Test Acc: 97.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch26.pth]
# Epoch [27/50] Train Loss: 0.0068 | Train Acc: 99.73% | Test Loss: 0.0798 | Test Acc: 97.00%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch27.pth]
# Epoch [28/50] Train Loss: 0.0023 | Train Acc: 100.00% | Test Loss: 0.0718 | Test Acc: 97.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch28.pth]
# Epoch [29/50] Train Loss: 0.0016 | Train Acc: 100.00% | Test Loss: 0.0697 | Test Acc: 96.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch29.pth]
# Epoch [30/50] Train Loss: 0.0009 | Train Acc: 100.00% | Test Loss: 0.0732 | Test Acc: 97.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch30.pth]
# Epoch [31/50] Train Loss: 0.0011 | Train Acc: 100.00% | Test Loss: 0.0686 | Test Acc: 97.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch31.pth]
# Epoch [32/50] Train Loss: 0.0009 | Train Acc: 100.00% | Test Loss: 0.0697 | Test Acc: 97.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch32.pth]
# Epoch [33/50] Train Loss: 0.0005 | Train Acc: 100.00% | Test Loss: 0.0684 | Test Acc: 97.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch33.pth]
# Epoch [34/50] Train Loss: 0.0004 | Train Acc: 100.00% | Test Loss: 0.0676 | Test Acc: 97.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch34.pth]
# Epoch [35/50] Train Loss: 0.0005 | Train Acc: 100.00% | Test Loss: 0.0668 | Test Acc: 97.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch35.pth]
# Epoch [36/50] Train Loss: 0.0005 | Train Acc: 100.00% | Test Loss: 0.0653 | Test Acc: 97.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch36.pth]
# Epoch [37/50] Train Loss: 0.0004 | Train Acc: 100.00% | Test Loss: 0.0651 | Test Acc: 97.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch37.pth]
# Epoch [38/50] Train Loss: 0.0005 | Train Acc: 100.00% | Test Loss: 0.0623 | Test Acc: 97.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch38.pth]
# Epoch [39/50] Train Loss: 0.0004 | Train Acc: 100.00% | Test Loss: 0.0649 | Test Acc: 97.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch39.pth]
# Epoch [40/50] Train Loss: 0.0005 | Train Acc: 100.00% | Test Loss: 0.0663 | Test Acc: 97.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch40.pth]
# Epoch [41/50] Train Loss: 0.0003 | Train Acc: 100.00% | Test Loss: 0.0645 | Test Acc: 97.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch41.pth]
# Epoch [42/50] Train Loss: 0.0114 | Train Acc: 99.73% | Test Loss: 0.0800 | Test Acc: 97.00%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch42.pth]
# Epoch [43/50] Train Loss: 0.0068 | Train Acc: 99.87% | Test Loss: 0.0831 | Test Acc: 97.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch43.pth]
# Epoch [44/50] Train Loss: 0.0018 | Train Acc: 100.00% | Test Loss: 0.0791 | Test Acc: 97.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch44.pth]
# Epoch [45/50] Train Loss: 0.0007 | Train Acc: 100.00% | Test Loss: 0.0761 | Test Acc: 97.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch45.pth]
# Epoch [46/50] Train Loss: 0.0005 | Train Acc: 100.00% | Test Loss: 0.0741 | Test Acc: 97.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch46.pth]
# Epoch [47/50] Train Loss: 0.0003 | Train Acc: 100.00% | Test Loss: 0.0731 | Test Acc: 97.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch47.pth]
# Epoch [48/50] Train Loss: 0.0004 | Train Acc: 100.00% | Test Loss: 0.0712 | Test Acc: 97.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch48.pth]
# Epoch [49/50] Train Loss: 0.0004 | Train Acc: 100.00% | Test Loss: 0.0702 | Test Acc: 97.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch49.pth]
# Epoch [50/50] Train Loss: 0.0004 | Train Acc: 100.00% | Test Loss: 0.0723 | Test Acc: 97.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_005_epoch50.pth]
#
# Final Metrics | Precision: 0.9742 | Recall: 0.9740 | F1: 0.9740
#
# MNIST Classical | noise=5.0%
#
#
# MNIST | noise=0.05 | train=1500 | test=500
# Epoch [1/50] Train Loss: 0.4922 | Train Acc: 90.60% | Test Loss: 0.1678 | Test Acc: 97.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch1.pth]
# Epoch [2/50] Train Loss: 0.0988 | Train Acc: 99.07% | Test Loss: 0.1122 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch2.pth]
# Epoch [3/50] Train Loss: 0.0343 | Train Acc: 99.93% | Test Loss: 0.0817 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch3.pth]
# Epoch [4/50] Train Loss: 0.0170 | Train Acc: 100.00% | Test Loss: 0.0672 | Test Acc: 98.00%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch4.pth]
# Epoch [5/50] Train Loss: 0.0117 | Train Acc: 100.00% | Test Loss: 0.0622 | Test Acc: 98.00%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch5.pth]
# Epoch [6/50] Train Loss: 0.0075 | Train Acc: 100.00% | Test Loss: 0.0598 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch6.pth]
# Epoch [7/50] Train Loss: 0.0058 | Train Acc: 100.00% | Test Loss: 0.0534 | Test Acc: 97.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch7.pth]
# Epoch [8/50] Train Loss: 0.0042 | Train Acc: 100.00% | Test Loss: 0.0543 | Test Acc: 97.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch8.pth]
# Epoch [9/50] Train Loss: 0.0035 | Train Acc: 100.00% | Test Loss: 0.0512 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch9.pth]
# Epoch [10/50] Train Loss: 0.0024 | Train Acc: 100.00% | Test Loss: 0.0470 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch10.pth]
# Epoch [11/50] Train Loss: 0.0023 | Train Acc: 100.00% | Test Loss: 0.0468 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch11.pth]
# Epoch [12/50] Train Loss: 0.0020 | Train Acc: 100.00% | Test Loss: 0.0458 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch12.pth]
# Epoch [13/50] Train Loss: 0.0015 | Train Acc: 100.00% | Test Loss: 0.0448 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch13.pth]
# Epoch [14/50] Train Loss: 0.0014 | Train Acc: 100.00% | Test Loss: 0.0460 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch14.pth]
# Epoch [15/50] Train Loss: 0.0011 | Train Acc: 100.00% | Test Loss: 0.0456 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch15.pth]
# Epoch [16/50] Train Loss: 0.0012 | Train Acc: 100.00% | Test Loss: 0.0474 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch16.pth]
# Epoch [17/50] Train Loss: 0.0011 | Train Acc: 100.00% | Test Loss: 0.0403 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch17.pth]
# Epoch [18/50] Train Loss: 0.0009 | Train Acc: 100.00% | Test Loss: 0.0422 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch18.pth]
# Epoch [19/50] Train Loss: 0.0008 | Train Acc: 100.00% | Test Loss: 0.0447 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch19.pth]
# Epoch [20/50] Train Loss: 0.0006 | Train Acc: 100.00% | Test Loss: 0.0452 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch20.pth]
# Epoch [21/50] Train Loss: 0.0008 | Train Acc: 100.00% | Test Loss: 0.0433 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch21.pth]
# Epoch [22/50] Train Loss: 0.0007 | Train Acc: 100.00% | Test Loss: 0.0445 | Test Acc: 97.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch22.pth]
# Epoch [23/50] Train Loss: 0.0007 | Train Acc: 100.00% | Test Loss: 0.0464 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch23.pth]
# Epoch [24/50] Train Loss: 0.0006 | Train Acc: 100.00% | Test Loss: 0.0428 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch24.pth]
# Epoch [25/50] Train Loss: 0.0006 | Train Acc: 100.00% | Test Loss: 0.0463 | Test Acc: 98.00%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch25.pth]
# Epoch [26/50] Train Loss: 0.0004 | Train Acc: 100.00% | Test Loss: 0.0364 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch26.pth]
# Epoch [27/50] Train Loss: 0.0004 | Train Acc: 100.00% | Test Loss: 0.0446 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch27.pth]
# Epoch [28/50] Train Loss: 0.0004 | Train Acc: 100.00% | Test Loss: 0.0447 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch28.pth]
# Epoch [29/50] Train Loss: 0.0004 | Train Acc: 100.00% | Test Loss: 0.0420 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch29.pth]
# Epoch [30/50] Train Loss: 0.0003 | Train Acc: 100.00% | Test Loss: 0.0415 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch30.pth]
# Epoch [31/50] Train Loss: 0.0003 | Train Acc: 100.00% | Test Loss: 0.0427 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch31.pth]
# Epoch [32/50] Train Loss: 0.0003 | Train Acc: 100.00% | Test Loss: 0.0395 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch32.pth]
# Epoch [33/50] Train Loss: 0.0003 | Train Acc: 100.00% | Test Loss: 0.0424 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch33.pth]
# Epoch [34/50] Train Loss: 0.0003 | Train Acc: 100.00% | Test Loss: 0.0401 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch34.pth]
# Epoch [35/50] Train Loss: 0.0003 | Train Acc: 100.00% | Test Loss: 0.0368 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch35.pth]
# Epoch [36/50] Train Loss: 0.0003 | Train Acc: 100.00% | Test Loss: 0.0385 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch36.pth]
# Epoch [37/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0384 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch37.pth]
# Epoch [38/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0390 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch38.pth]
# Epoch [39/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0391 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch39.pth]
# Epoch [40/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0399 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch40.pth]
# Epoch [41/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0366 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch41.pth]
# Epoch [42/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0428 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch42.pth]
# Epoch [43/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0409 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch43.pth]
# Epoch [44/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0393 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch44.pth]
# Epoch [45/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0395 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch45.pth]
# Epoch [46/50] Train Loss: 0.0001 | Train Acc: 100.00% | Test Loss: 0.0401 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch46.pth]
# Epoch [47/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0419 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch47.pth]
# Epoch [48/50] Train Loss: 0.0001 | Train Acc: 100.00% | Test Loss: 0.0382 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch48.pth]
# Epoch [49/50] Train Loss: 0.0001 | Train Acc: 100.00% | Test Loss: 0.0352 | Test Acc: 99.00%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch49.pth]
# Epoch [50/50] Train Loss: 0.0001 | Train Acc: 100.00% | Test Loss: 0.0374 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_05_epoch50.pth]
#
# Final Metrics | Precision: 0.9881 | Recall: 0.9880 | F1: 0.9880
#
# MNIST Classical | noise=10.0%
#
#
# MNIST | noise=0.1 | train=1500 | test=500
# Epoch [1/50] Train Loss: 0.4436 | Train Acc: 92.27% | Test Loss: 0.1596 | Test Acc: 97.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch1.pth]
# Epoch [2/50] Train Loss: 0.0858 | Train Acc: 99.47% | Test Loss: 0.0996 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch2.pth]
# Epoch [3/50] Train Loss: 0.0355 | Train Acc: 99.73% | Test Loss: 0.0694 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch3.pth]
# Epoch [4/50] Train Loss: 0.0181 | Train Acc: 100.00% | Test Loss: 0.0615 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch4.pth]
# Epoch [5/50] Train Loss: 0.0109 | Train Acc: 99.93% | Test Loss: 0.0616 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch5.pth]
# Epoch [6/50] Train Loss: 0.0072 | Train Acc: 100.00% | Test Loss: 0.0565 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch6.pth]
# Epoch [7/50] Train Loss: 0.0080 | Train Acc: 99.93% | Test Loss: 0.0657 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch7.pth]
# Epoch [8/50] Train Loss: 0.0047 | Train Acc: 100.00% | Test Loss: 0.0457 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch8.pth]
# Epoch [9/50] Train Loss: 0.0031 | Train Acc: 100.00% | Test Loss: 0.0450 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch9.pth]
# Epoch [10/50] Train Loss: 0.0025 | Train Acc: 100.00% | Test Loss: 0.0459 | Test Acc: 99.00%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch10.pth]
# Epoch [11/50] Train Loss: 0.0025 | Train Acc: 100.00% | Test Loss: 0.0419 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch11.pth]
# Epoch [12/50] Train Loss: 0.0017 | Train Acc: 100.00% | Test Loss: 0.0442 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch12.pth]
# Epoch [13/50] Train Loss: 0.0015 | Train Acc: 100.00% | Test Loss: 0.0402 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch13.pth]
# Epoch [14/50] Train Loss: 0.0019 | Train Acc: 100.00% | Test Loss: 0.0429 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch14.pth]
# Epoch [15/50] Train Loss: 0.0054 | Train Acc: 99.93% | Test Loss: 0.2147 | Test Acc: 93.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch15.pth]
# Epoch [16/50] Train Loss: 0.0052 | Train Acc: 99.93% | Test Loss: 0.0409 | Test Acc: 99.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch16.pth]
# Epoch [17/50] Train Loss: 0.0022 | Train Acc: 100.00% | Test Loss: 0.0410 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch17.pth]
# Epoch [18/50] Train Loss: 0.0084 | Train Acc: 99.73% | Test Loss: 0.2920 | Test Acc: 88.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch18.pth]
# Epoch [19/50] Train Loss: 0.0195 | Train Acc: 99.60% | Test Loss: 0.0949 | Test Acc: 97.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch19.pth]
# Epoch [20/50] Train Loss: 0.0112 | Train Acc: 99.67% | Test Loss: 0.0671 | Test Acc: 97.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch20.pth]
# Epoch [21/50] Train Loss: 0.0099 | Train Acc: 99.67% | Test Loss: 0.0637 | Test Acc: 97.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch21.pth]
# Epoch [22/50] Train Loss: 0.0136 | Train Acc: 99.67% | Test Loss: 0.0581 | Test Acc: 97.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch22.pth]
# Epoch [23/50] Train Loss: 0.0045 | Train Acc: 99.93% | Test Loss: 0.0475 | Test Acc: 97.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch23.pth]
# Epoch [24/50] Train Loss: 0.0022 | Train Acc: 100.00% | Test Loss: 0.0426 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch24.pth]
# Epoch [25/50] Train Loss: 0.0013 | Train Acc: 100.00% | Test Loss: 0.0517 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch25.pth]
# Epoch [26/50] Train Loss: 0.0010 | Train Acc: 100.00% | Test Loss: 0.0457 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch26.pth]
# Epoch [27/50] Train Loss: 0.0011 | Train Acc: 100.00% | Test Loss: 0.0511 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch27.pth]
# Epoch [28/50] Train Loss: 0.0007 | Train Acc: 100.00% | Test Loss: 0.0450 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch28.pth]
# Epoch [29/50] Train Loss: 0.0004 | Train Acc: 100.00% | Test Loss: 0.0404 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch29.pth]
# Epoch [30/50] Train Loss: 0.0005 | Train Acc: 100.00% | Test Loss: 0.0414 | Test Acc: 98.80%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch30.pth]
# Epoch [31/50] Train Loss: 0.0004 | Train Acc: 100.00% | Test Loss: 0.0383 | Test Acc: 99.00%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch31.pth]
# Epoch [32/50] Train Loss: 0.0004 | Train Acc: 100.00% | Test Loss: 0.0398 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch32.pth]
# Epoch [33/50] Train Loss: 0.0003 | Train Acc: 100.00% | Test Loss: 0.0436 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch33.pth]
# Epoch [34/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0426 | Test Acc: 98.00%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch34.pth]
# Epoch [35/50] Train Loss: 0.0003 | Train Acc: 100.00% | Test Loss: 0.0411 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch35.pth]
# Epoch [36/50] Train Loss: 0.0007 | Train Acc: 100.00% | Test Loss: 0.0462 | Test Acc: 98.00%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch36.pth]
# Epoch [37/50] Train Loss: 0.0006 | Train Acc: 100.00% | Test Loss: 0.0434 | Test Acc: 97.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch37.pth]
# Epoch [38/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0437 | Test Acc: 98.00%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch38.pth]
# Epoch [39/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0452 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch39.pth]
# Epoch [40/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0454 | Test Acc: 98.00%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch40.pth]
# Epoch [41/50] Train Loss: 0.0001 | Train Acc: 100.00% | Test Loss: 0.0427 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch41.pth]
# Epoch [42/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0434 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch42.pth]
# Epoch [43/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0422 | Test Acc: 98.20%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch43.pth]
# Epoch [44/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0392 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch44.pth]
# Epoch [45/50] Train Loss: 0.0001 | Train Acc: 100.00% | Test Loss: 0.0449 | Test Acc: 98.00%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch45.pth]
# Epoch [46/50] Train Loss: 0.0003 | Train Acc: 100.00% | Test Loss: 0.0408 | Test Acc: 98.40%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch46.pth]
# Epoch [47/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0391 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch47.pth]
# Epoch [48/50] Train Loss: 0.0001 | Train Acc: 100.00% | Test Loss: 0.0384 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch48.pth]
# Epoch [49/50] Train Loss: 0.0002 | Train Acc: 100.00% | Test Loss: 0.0372 | Test Acc: 98.60%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch49.pth]
# Epoch [50/50] Train Loss: 0.0001 | Train Acc: 100.00% | Test Loss: 0.0381 | Test Acc: 99.00%
#   [Saved checkpoint: ./mnist_classical_checkpoints/ckpt_noise0_1_epoch50.pth]
#
# Final Metrics | Precision: 0.9902 | Recall: 0.9900 | F1: 0.9900
#
# [All results saved to ./mnist_classical_checkpoints]
#
# All experiments complete.

# %%
def plot_metrics(results):
    noise_labels = {0.0: "0% noise", 0.005: "0.5% noise", 0.05: "5% noise", 0.10: "10% noise"}
    colors       = {0.0: "#2196F3",  0.005: "#4CAF50",    0.05: "#FF9800",  0.10: "#F44336"}
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    fig.suptitle("Classical AlexNet: MNIST", fontsize=14, fontweight="bold")
    ax_loss, ax_acc = axes
    for noise, history in results.items():
        c = colors[noise]; l = noise_labels[noise]
        ep = list(range(1, len(history["train_loss"]) + 1))
        ax_loss.plot(ep, history["train_loss"], color=c, ls="-",  label=f"{l} (train)")
        ax_loss.plot(ep, history["test_loss"],  color=c, ls="--", label=f"{l} (test)")
        ax_acc.plot(ep,  [a*100 for a in history["train_acc"]], color=c, ls="-",  label=f"{l} (train)")
        ax_acc.plot(ep,  [a*100 for a in history["test_acc"]],  color=c, ls="--", label=f"{l} (test)")
    for ax, ylabel, title in zip(
        [ax_loss, ax_acc],
        ["Cross-Entropy Loss", "Accuracy (%)"],
        ["Loss Curves", "Accuracy Curves"]
    ):
        ax.set_xlabel("Epoch"); ax.set_ylabel(ylabel); ax.set_title(title)
        ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
        ax.legend(fontsize=8); ax.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig(os.path.join(SAVE_DIR, "classical_alexnet_mnist.png"), dpi=150, bbox_inches="tight")
    plt.show()

# %%
def plot_confusion_matrices(results, class_names):
    noise_labels = {0.0: "0%", 0.005: "0.5%", 0.05: "5%", 0.10: "10%"}
    fig, axes = plt.subplots(1, 4, figsize=(24, 5))
    fig.suptitle("Classical AlexNet: MNIST Confusion Matrices", fontsize=14, fontweight="bold")
    for ax, (noise, history) in zip(axes, results.items()):
        sns.heatmap(
            history["cm"], annot=True, fmt="d", cmap="Blues",
            xticklabels=class_names, yticklabels=class_names, ax=ax
        )
        ax.set_title(f"Noise: {noise_labels[noise]}")
        ax.set_xlabel("Predicted")
        ax.set_ylabel("True")
    plt.tight_layout()
    plt.savefig(os.path.join(SAVE_DIR, "classical_alexnet_mnist_cm.png"), dpi=150, bbox_inches="tight")
    plt.show()

# %%
def print_summary(results):
    noise_labels = {0.0: "0%", 0.005: "0.5%", 0.05: "5%", 0.10: "10%"}
    header = f"{'Noise':>8} {'Test Acc':>10} {'Test Loss':>12} {'Precision':>12} {'Recall':>10} {'F1':>10}"
    print("\nMNIST Classical AlexNet: Results")
    print("\n")
    print(header)
    print("\n")
    for noise, history in results.items():
        print(
            f"{noise_labels[noise]:>8} "
            f"{history['test_acc'][-1]*100:>9.2f}% "
            f"{history['test_loss'][-1]:>12.4f} "
            f"{history['precision']:>12.4f} "
            f"{history['recall']:>10.4f} "
            f"{history['f1']:>10.4f}"
        )
    print("\n")

mnist_classes = [str(i) for i in range(10)]
plot_metrics(results)
plot_confusion_matrices(results, mnist_classes)
print_summary(results)
# Out:
# MNIST Classical AlexNet: Results
#
#
#    Noise   Test Acc    Test Loss    Precision     Recall         F1
#
#
#       0%     99.20%       0.0404       0.9921     0.9920     0.9920
#     0.5%     97.40%       0.0723       0.9742     0.9740     0.9740
#       5%     98.80%       0.0374       0.9881     0.9880     0.9880
#      10%     99.00%       0.0381       0.9902     0.9900     0.9900
